# %%
# !kaggle datasets download -d yousefeldaly23/diarization-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/yousefeldaly23/diarization-dataset
# License(s): unknown
# Downloading diarization-dataset.zip to /kaggle/working
# 100%|████████████████████████████████████████▉| 292M/292M [00:01<00:00, 224MB/s]
# 100%|█████████████████████████████████████████| 292M/292M [00:01<00:00, 243MB/s]

# %%
# !unzip '/kaggle/working/diarization-dataset.zip'
# Out:
# Archive:  /kaggle/working/diarization-dataset.zip
#   inflating: wavs/audio_sample_1.wav
#   inflating: wavs/audio_sample_10.wav
#   inflating: wavs/audio_sample_100.wav
#   inflating: wavs/audio_sample_101.wav
#   inflating: wavs/audio_sample_102.wav
#   inflating: wavs/audio_sample_103.wav
#   inflating: wavs/audio_sample_104.wav
#   inflating: wavs/audio_sample_106.wav
#   inflating: wavs/audio_sample_108.wav
#   inflating: wavs/audio_sample_109.wav
#   inflating: wavs/audio_sample_11.wav
#   inflating: wavs/audio_sample_110.wav
#   inflating: wavs/audio_sample_112.wav
#   inflating: wavs/audio_sample_113.wav
#   inflating: wavs/audio_sample_117.wav
#   inflating: wavs/audio_sample_118.wav
#   inflating: wavs/audio_sample_119.wav
#   inflating: wavs/audio_sample_12.wav
#   inflating: wavs/audio_sample_120.wav
#   inflating: wavs/audio_sample_124.wav
#   inflating: wavs/audio_sample_125.wav
#   inflating: wavs/audio_sample_126.wav
#   inflating: wavs/audio_sample_127.wav
#   inflating: wavs/audio_sample_128.wav
#   inflating: wavs/audio_sample_129.wav
#   inflating: wavs/audio_sample_13.wav
#   inflating: wavs/audio_sample_132.wav
#   inflating: wavs/audio_sample_135.wav
#   inflating: wavs/audio_sample_136.wav
#   inflating: wavs/audio_sample_138.wav
#   inflating: wavs/audio_sample_139.wav
#   inflating: wavs/audio_sample_14.wav
#   inflating: wavs/audio_sample_140.wav
#   inflating: wavs/audio_sample_141.wav
#   inflating: wavs/audio_sample_144.wav
#   inflating: wavs/audio_sample_146.wav
#   inflating: wavs/audio_sample_147.wav
#   inflating: wavs/audio_sample_149.wav
#   inflating: wavs/audio_sample_150.wav
#   inflating: wavs/audio_sample_151.wav
#   inflating: wavs/audio_sample_153.wav
#   inflating: wavs/audio_sample_154.wav
#   inflating: wavs/audio_sample_155.wav
#   inflating: wavs/audio_sample_159.wav
#   inflating: wavs/audio_sample_16.wav
#   inflating: wavs/audio_sample_160.wav
#   inflating: wavs/audio_sample_161.wav
#   inflating: wavs/audio_sample_162.wav
#   inflating: wavs/audio_sample_164.wav
#   inflating: wavs/audio_sample_167.wav
#   inflating: wavs/audio_sample_170.wav
#   inflating: wavs/audio_sample_172.wav
#   inflating: wavs/audio_sample_175.wav
#   inflating: wavs/audio_sample_177.wav
#   inflating: wavs/audio_sample_18.wav
#   inflating: wavs/audio_sample_180.wav
#   inflating: wavs/audio_sample_183.wav
#   inflating: wavs/audio_sample_186.wav
#   inflating: wavs/audio_sample_187.wav
#   inflating: wavs/audio_sample_188.wav
#   inflating: wavs/audio_sample_189.wav
#   inflating: wavs/audio_sample_19.wav
#   inflating: wavs/audio_sample_191.wav
#   inflating: wavs/audio_sample_192.wav
#   inflating: wavs/audio_sample_194.wav
#   inflating: wavs/audio_sample_195.wav
#   inflating: wavs/audio_sample_196.wav
#   inflating: wavs/audio_sample_197.wav
#   inflating: wavs/audio_sample_198.wav
#   inflating: wavs/audio_sample_199.wav
#   inflating: wavs/audio_sample_2.wav
#   inflating: wavs/audio_sample_20.wav
#   inflating: wavs/audio_sample_200.wav
#   inflating: wavs/audio_sample_201.wav
#   inflating: wavs/audio_sample_21.wav
#   inflating: wavs/audio_sample_22.wav
#   inflating: wavs/audio_sample_24.wav
#   inflating: wavs/audio_sample_25.wav
#   inflating: wavs/audio_sample_28.wav
#   inflating: wavs/audio_sample_29.wav
#   inflating: wavs/audio_sample_3.wav
#   inflating: wavs/audio_sample_30.wav
#   inflating: wavs/audio_sample_31.wav
#   inflating: wavs/audio_sample_33.wav
#   inflating: wavs/audio_sample_34.wav
#   inflating: wavs/audio_sample_35.wav
#   inflating: wavs/audio_sample_38.wav
#   inflating: wavs/audio_sample_39.wav
#   inflating: wavs/audio_sample_40.wav
#   inflating: wavs/audio_sample_41.wav
#   inflating: wavs/audio_sample_42.wav
#   inflating: wavs/audio_sample_43.wav
#   inflating: wavs/audio_sample_44.wav
#   inflating: wavs/audio_sample_46.wav
#   inflating: wavs/audio_sample_47.wav
#   inflating: wavs/audio_sample_49.wav
#   inflating: wavs/audio_sample_50.wav
#   inflating: wavs/audio_sample_51.wav
#   inflating: wavs/audio_sample_52.wav
#   inflating: wavs/audio_sample_55.wav
#   inflating: wavs/audio_sample_56.wav
#   inflating: wavs/audio_sample_57.wav
#   inflating: wavs/audio_sample_59.wav
#   inflating: wavs/audio_sample_6.wav
#   inflating: wavs/audio_sample_60.wav
#   inflating: wavs/audio_sample_63.wav
#   inflating: wavs/audio_sample_64.wav
#   inflating: wavs/audio_sample_65.wav
#   inflating: wavs/audio_sample_69.wav
#   inflating: wavs/audio_sample_72.wav
#   inflating: wavs/audio_sample_73.wav
#   inflating: wavs/audio_sample_74.wav
#   inflating: wavs/audio_sample_75.wav
#   inflating: wavs/audio_sample_76.wav
#   inflating: wavs/audio_sample_78.wav
#   inflating: wavs/audio_sample_79.wav
#   inflating: wavs/audio_sample_80.wav
#   inflating: wavs/audio_sample_81.wav
#   inflating: wavs/audio_sample_82.wav
#   inflating: wavs/audio_sample_83.wav
#   inflating: wavs/audio_sample_85.wav
#   inflating: wavs/audio_sample_87.wav
#   inflating: wavs/audio_sample_88.wav
#   inflating: wavs/audio_sample_89.wav
#   inflating: wavs/audio_sample_9.wav
#   inflating: wavs/audio_sample_90.wav
#   inflating: wavs/audio_sample_92.wav
#   inflating: wavs/audio_sample_94.wav
#   inflating: wavs/audio_sample_95.wav
#   inflating: wavs/audio_sample_96.wav
#   inflating: wavs/audio_sample_97.wav

# %%
# !kaggle datasets download -d yousefeldaly/asr-model-quartznet
# Out:
# Dataset URL: https://www.kaggle.com/datasets/yousefeldaly/asr-model-quartznet
# License(s): unknown
# Downloading asr-model-quartznet.zip to /kaggle/working
# 100%|█████████████████████████████████████▉| 46.0M/46.1M [00:13<00:00, 3.87MB/s]
# 100%|██████████████████████████████████████| 46.1M/46.1M [00:13<00:00, 3.56MB/s]

# %%
# !unzip '/kaggle/working/asr-model-quartznet.zip'
# Out:
# Archive:  /kaggle/working/asr-model-quartznet.zip
#   inflating: quartznet-CTC-Char-Medium.nemo

# %%
dataset_path = "/kaggle/working/wavs"

# %%
# !git clone https://github.com/NVIDIA/NeMo.git
# Out:
# Cloning into 'NeMo'...
# remote: Enumerating objects: 169293, done.
# remote: Counting objects: 100% (2645/2645), done.
# remote: Compressing objects: 100% (1386/1386), done.
# remote: Total 169293 (delta 1795), reused 1883 (delta 1208), pack-reused 166648
# Receiving objects: 100% (169293/169293), 255.56 MiB | 35.70 MiB/s, done.
# Resolving deltas: 100% (127295/127295), done.

# %%
# !pip install nemo_toolkit['asr']
# Out:
# Collecting nemo_toolkit[asr]
#   Downloading nemo_toolkit-1.23.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (0.23.4)
# Requirement already satisfied: numba in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (0.58.1)
# Requirement already satisfied: numpy>=1.22 in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (1.26.4)
# Requirement already satisfied: onnx>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (1.16.1)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (2.9.0.post0)
# Requirement already satisfied: ruamel.yaml in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (0.18.5)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (1.2.2)
# Requirement already satisfied: setuptools>=65.5.1 in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (69.0.3)
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (2.15.1)
# Requirement already satisfied: text-unidecode in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (1.3)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (2.1.2)
# Requirement already satisfied: tqdm>=4.41.0 in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (4.66.4)
# Collecting triton (from nemo_toolkit[asr])
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting wget (from nemo_toolkit[asr])
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (1.14.1)
# Collecting braceexpand (from nemo_toolkit[asr])
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting editdistance (from nemo_toolkit[asr])
#   Downloading editdistance-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting g2p-en (from nemo_toolkit[asr])
#   Downloading g2p_en-2.1.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (7.7.1)
# Collecting jiwer (from nemo_toolkit[asr])
#   Downloading jiwer-3.0.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting kaldi-python-io (from nemo_toolkit[asr])
#   Downloading kaldi-python-io-1.2.2.tar.gz (8.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting kaldiio (from nemo_toolkit[asr])
#   Downloading kaldiio-2.18.0-py3-none-any.whl.metadata (13 kB)
# Collecting lhotse>=1.20.0 (from nemo_toolkit[asr])
#   Downloading lhotse-1.25.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: librosa>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (0.10.2.post1)
# Requirement already satisfied: marshmallow in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (3.21.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (3.7.5)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (21.3)
# Collecting pyannote.core (from nemo_toolkit[asr])
#   Downloading pyannote.core-5.0.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting pyannote.metrics (from nemo_toolkit[asr])
#   Downloading pyannote.metrics-3.2.1-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: pydub in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (0.25.1)
# Collecting pyloudnorm (from nemo_toolkit[asr])
#   Downloading pyloudnorm-0.1.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting resampy (from nemo_toolkit[asr])
#   Downloading resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: scipy>=0.14 in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (1.11.4)
# Requirement already satisfied: soundfile in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (0.12.1)
# Collecting sox (from nemo_toolkit[asr])
#   Downloading sox-1.5.0.tar.gz (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting texterrors (from nemo_toolkit[asr])
#   Downloading texterrors-0.5.1.tar.gz (23 kB)
#   Preparing metadata (setup.py) ... done
# Collecting hydra-core<=1.3.2,>1.3 (from nemo_toolkit[asr])
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting omegaconf<=2.3 (from nemo_toolkit[asr])
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting pytorch-lightning<=2.0.7,>=2.0 (from nemo_toolkit[asr])
#   Downloading pytorch_lightning-2.0.7-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: torchmetrics>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (1.4.0.post0)
# Requirement already satisfied: transformers>=4.36.0 in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (4.42.3)
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (0.17.4)
# Collecting webdataset<=0.1.62,>=0.1.48 (from nemo_toolkit[asr])
#   Downloading webdataset-0.1.62-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (2.20.0)
# Collecting inflect (from nemo_toolkit[asr])
#   Downloading inflect-7.3.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (2.2.2)
# Collecting sacremoses>=0.0.43 (from nemo_toolkit[asr])
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: sentencepiece<1.0.0 in /opt/conda/lib/python3.10/site-packages (from nemo_toolkit[asr]) (0.2.0)
# Collecting youtokentome>=1.0.5 (from nemo_toolkit[asr])
#   Downloading youtokentome-1.0.6.tar.gz (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 5.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core<=1.3.2,>1.3->nemo_toolkit[asr])
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: audioread>=2.1.9 in /opt/conda/lib/python3.10/site-packages (from lhotse>=1.20.0->nemo_toolkit[asr]) (3.0.1)
# Requirement already satisfied: click>=7.1.1 in /opt/conda/lib/python3.10/site-packages (from lhotse>=1.20.0->nemo_toolkit[asr]) (8.1.7)
# Requirement already satisfied: cytoolz>=0.10.1 in /opt/conda/lib/python3.10/site-packages (from lhotse>=1.20.0->nemo_toolkit[asr]) (0.12.3)
# Collecting intervaltree>=3.1.0 (from lhotse>=1.20.0->nemo_toolkit[asr])
#   Downloading intervaltree-3.1.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from lhotse>=1.20.0->nemo_toolkit[asr]) (6.0.1)
# Requirement already satisfied: tabulate>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from lhotse>=1.20.0->nemo_toolkit[asr]) (0.9.0)
# Collecting lilcom>=1.1.0 (from lhotse>=1.20.0->nemo_toolkit[asr])
#   Downloading lilcom-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: joblib>=0.14 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.10.0->nemo_toolkit[asr]) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.10.0->nemo_toolkit[asr]) (5.1.1)
# Requirement already satisfied: pooch>=1.1 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.10.0->nemo_toolkit[asr]) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.10.0->nemo_toolkit[asr]) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.10.0->nemo_toolkit[asr]) (4.9.0)
# Requirement already satisfied: lazy-loader>=0.1 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.10.0->nemo_toolkit[asr]) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /opt/conda/lib/python3.10/site-packages (from librosa>=0.10.0->nemo_toolkit[asr]) (1.0.7)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba->nemo_toolkit[asr]) (0.41.1)
# Requirement already satisfied: protobuf>=3.20.2 in /opt/conda/lib/python3.10/site-packages (from onnx>=1.7.0->nemo_toolkit[asr]) (3.20.3)
# Requirement already satisfied: fsspec>2021.06.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning<=2.0.7,>=2.0->nemo_toolkit[asr]) (2024.5.0)
# Requirement already satisfied: lightning-utilities>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning<=2.0.7,>=2.0->nemo_toolkit[asr]) (0.11.3.post0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->nemo_toolkit[asr]) (3.1.1)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from sacremoses>=0.0.43->nemo_toolkit[asr]) (2023.12.25)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->nemo_toolkit[asr]) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/lib/python3.10/site-packages (from soundfile->nemo_toolkit[asr]) (1.16.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->nemo_toolkit[asr]) (3.13.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->nemo_toolkit[asr]) (1.13.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->nemo_toolkit[asr]) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->nemo_toolkit[asr]) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers>=4.36.0->nemo_toolkit[asr]) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.36.0->nemo_toolkit[asr]) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.36.0->nemo_toolkit[asr]) (0.19.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets->nemo_toolkit[asr]) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in /opt/conda/lib/python3.10/site-packages (from datasets->nemo_toolkit[asr]) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets->nemo_toolkit[asr]) (0.3.8)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets->nemo_toolkit[asr]) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets->nemo_toolkit[asr]) (0.70.16)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets->nemo_toolkit[asr]) (3.9.1)
# Requirement already satisfied: nltk>=3.2.4 in /opt/conda/lib/python3.10/site-packages (from g2p-en->nemo_toolkit[asr]) (3.2.4)
# Collecting distance>=0.1.3 (from g2p-en->nemo_toolkit[asr])
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.3/180.3 kB 9.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: more-itertools>=8.5.0 in /opt/conda/lib/python3.10/site-packages (from inflect->nemo_toolkit[asr]) (10.2.0)
# Requirement already satisfied: typeguard>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from inflect->nemo_toolkit[asr]) (4.1.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->nemo_toolkit[asr]) (6.28.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->nemo_toolkit[asr]) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->nemo_toolkit[asr]) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->nemo_toolkit[asr]) (3.6.7)
# Requirement already satisfied: ipython>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->nemo_toolkit[asr]) (8.20.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->nemo_toolkit[asr]) (3.0.9)
# Collecting rapidfuzz<4,>=3 (from jiwer->nemo_toolkit[asr])
#   Downloading rapidfuzz-3.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->nemo_toolkit[asr]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->nemo_toolkit[asr]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->nemo_toolkit[asr]) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->nemo_toolkit[asr]) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->nemo_toolkit[asr]) (9.5.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil->nemo_toolkit[asr]) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->nemo_toolkit[asr]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->nemo_toolkit[asr]) (2023.4)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /opt/conda/lib/python3.10/site-packages (from pyannote.core->nemo_toolkit[asr]) (2.4.0)
# Collecting pyannote.database>=4.0.1 (from pyannote.metrics->nemo_toolkit[asr])
#   Downloading pyannote.database-5.1.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: docopt>=0.6.2 in /opt/conda/lib/python3.10/site-packages (from pyannote.metrics->nemo_toolkit[asr]) (0.6.2)
# Requirement already satisfied: future>=0.16.0 in /opt/conda/lib/python3.10/site-packages (from pyloudnorm->nemo_toolkit[asr]) (1.0.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/conda/lib/python3.10/site-packages (from ruamel.yaml->nemo_toolkit[asr]) (0.2.7)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.10/site-packages (from tensorboard->nemo_toolkit[asr]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tensorboard->nemo_toolkit[asr]) (1.60.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard->nemo_toolkit[asr]) (2.26.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard->nemo_toolkit[asr]) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard->nemo_toolkit[asr]) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard->nemo_toolkit[asr]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard->nemo_toolkit[asr]) (3.0.3)
# Requirement already satisfied: pybind11 in /opt/conda/lib/python3.10/site-packages (from texterrors->nemo_toolkit[asr]) (2.13.1)
# Collecting plac (from texterrors->nemo_toolkit[asr])
#   Downloading plac-1.4.3-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: loguru in /opt/conda/lib/python3.10/site-packages (from texterrors->nemo_toolkit[asr]) (0.7.2)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from texterrors->nemo_toolkit[asr]) (2.4.0)
# Collecting Levenshtein (from texterrors->nemo_toolkit[asr])
#   Downloading Levenshtein-0.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb->nemo_toolkit[asr]) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb->nemo_toolkit[asr]) (3.1.41)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb->nemo_toolkit[asr]) (3.11.0)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb->nemo_toolkit[asr]) (5.9.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb->nemo_toolkit[asr]) (2.8.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb->nemo_toolkit[asr]) (1.3.3)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0->soundfile->nemo_toolkit[asr]) (2.21)
# Requirement already satisfied: toolz>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from cytoolz>=0.10.1->lhotse>=1.20.0->nemo_toolkit[asr]) (0.12.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->nemo_toolkit[asr]) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->nemo_toolkit[asr]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->nemo_toolkit[asr]) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->nemo_toolkit[asr]) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->nemo_toolkit[asr]) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->nemo_toolkit[asr]) (4.0.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb->nemo_toolkit[asr]) (4.0.11)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[asr]) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[asr]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[asr]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->nemo_toolkit[asr]) (1.3.1)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (5.7.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (1.5.8)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (6.3.3)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (2.17.2)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (0.6.2)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (4.8.0)
# Requirement already satisfied: typer>=0.12.1 in /opt/conda/lib/python3.10/site-packages (from pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]) (0.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.36.0->nemo_toolkit[asr]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.36.0->nemo_toolkit[asr]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.36.0->nemo_toolkit[asr]) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.36.0->nemo_toolkit[asr]) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->nemo_toolkit[asr]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard->nemo_toolkit[asr]) (2.1.3)
# Requirement already satisfied: notebook>=4.4.1 in /opt/conda/lib/python3.10/site-packages (from widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (6.5.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->nemo_toolkit[asr]) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (0.8.3)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (0.4)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (23.1.0)
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (6.4.5)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.18.0)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.19.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (0.2.13)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[asr]) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->nemo_toolkit[asr]) (3.2.2)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from typer>=0.12.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/conda/lib/python3.10/site-packages (from typer>=0.12.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]) (13.7.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (2.12.5)
# Requirement already satisfied: notebook-shim>=0.2.3 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.2.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.3.0)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (6.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (1.5.0)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.6.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (4.12.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.5.13)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (4.20.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.12.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]) (3.0.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (21.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.16.2)
# Requirement already satisfied: anyio>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (4.2.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.5.1)
# Requirement already satisfied: overrides in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (7.4.0)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (1.7.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]) (0.1.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (2.5)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (1.3.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.1.1)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (2.4)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (2.8.19.20240106)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 8.6 MB/s eta 0:00:00
# Downloading lhotse-1.25.0-py3-none-any.whl (793 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.6/793.6 kB 28.4 MB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.7 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.0.7-py3-none-any.whl (724 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.0/725.0 kB 31.7 MB/s eta 0:00:00
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 34.8 MB/s eta 0:00:00
# Downloading webdataset-0.1.62-py3-none-any.whl (32 kB)
# Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Downloading editdistance-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (401 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.8/401.8 kB 22.1 MB/s eta 0:00:00
# Downloading g2p_en-2.1.0-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 67.0 MB/s eta 0:00:00:00:01
# Downloading inflect-7.3.1-py3-none-any.whl (34 kB)
# Downloading jiwer-3.0.4-py3-none-any.whl (21 kB)
# Downloading kaldiio-2.18.0-py3-none-any.whl (28 kB)
# Downloading nemo_toolkit-1.23.0-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 63.4 MB/s eta 0:00:00:00:01
# Downloading pyannote.core-5.0.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 3.7 MB/s eta 0:00:00
# Downloading pyannote.metrics-3.2.1-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 3.2 MB/s eta 0:00:00
# Downloading pyloudnorm-0.1.1-py3-none-any.whl (9.6 kB)
# Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 63.1 MB/s eta 0:00:00:00:01
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 7.8 MB/s eta 0:00:00:00:0100:01
# Downloading lilcom-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.7 MB/s eta 0:00:00
# Downloading pyannote.database-5.1.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 2.6 MB/s eta 0:00:00
# Downloading rapidfuzz-3.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 70.8 MB/s eta 0:00:00:00:01
# Downloading Levenshtein-0.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 10.4 MB/s eta 0:00:00
# Downloading plac-1.4.3-py2.py3-none-any.whl (22 kB)
# Building wheels for collected packages: antlr4-python3-runtime, youtokentome, kaldi-python-io, sox, texterrors, wget, distance, intervaltree
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=39d0e91b13bd6496a0e5fa17ec1832648d741fd438d72b6ae8629e4b5aec8592
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for youtokentome (setup.py) ... done
#   Created wheel for youtokentome: filename=youtokentome-1.0.6-cp310-cp310-linux_x86_64.whl size=187956 sha256=21d4412ab4b05a62c3cb05afda6c8470af3c26c9ed1036460f0adbd3d43c603f
#   Stored in directory: /root/.cache/pip/wheels/df/85/f8/301d2ba45f43f30bed2fe413efa760bc726b8b660ed9c2900c
#   Building wheel for kaldi-python-io (setup.py) ... done
#   Created wheel for kaldi-python-io: filename=kaldi_python_io-1.2.2-py3-none-any.whl size=8949 sha256=626f629d73c154db0a89f78643b119b5792f0632c3bf417e1254c6429e441774
#   Stored in directory: /root/.cache/pip/wheels/b7/23/5f/49d3a826be576faf61d84e8028e1914bb36a5586ee2613b087
#   Building wheel for sox (setup.py) ... done
#   Created wheel for sox: filename=sox-1.5.0-py3-none-any.whl size=40037 sha256=b64a2bfde4d5b4398fb0759fccb1c3a36987e6e5853a34f042992c46a807b8d1
#   Stored in directory: /root/.cache/pip/wheels/74/e7/7b/8033be3ec5e4994595d01269fc9657c8fd83a0dcbf8536666a
#   Building wheel for texterrors (setup.py) ... done
#   Created wheel for texterrors: filename=texterrors-0.5.1-cp310-cp310-linux_x86_64.whl size=99550 sha256=fe5f1af5994628c65cf07d5c77d47dca19d912e89f9c4921b3c0c7cbc81cbc99
#   Stored in directory: /root/.cache/pip/wheels/64/b3/44/612e60c5d0d1f956213e08ae2c3f73443fde51878c778a9a38
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=d3cb5aed2d048b93c2954edc4e9be4c555c76b10ab04702565b908886a1e7543
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
#   Building wheel for distance (setup.py) ... done
#   Created wheel for distance: filename=Distance-0.1.3-py3-none-any.whl size=16258 sha256=b229c3aadd34e7191847c0b7d0a6eb1334a8db5b8dec67de6c313f811579ebd6
#   Stored in directory: /root/.cache/pip/wheels/e8/bb/de/f71bf63559ea9a921059a5405806f7ff6ed612a9231c4a9309
#   Building wheel for intervaltree (setup.py) ... done
#   Created wheel for intervaltree: filename=intervaltree-3.1.0-py2.py3-none-any.whl size=26095 sha256=5e8eaf5b7e2a7bfba7c6559f9f7cbb02ab1c17e19fe63e66dea1ff158c1479ca
#   Stored in directory: /root/.cache/pip/wheels/fa/80/8c/43488a924a046b733b64de3fac99252674c892a4c3801c0a61
# Successfully built antlr4-python3-runtime youtokentome kaldi-python-io sox texterrors wget distance intervaltree
# Installing collected packages: wget, plac, distance, braceexpand, antlr4-python3-runtime, youtokentome, webdataset, triton, sox, sacremoses, rapidfuzz, omegaconf, lilcom, kaldiio, kaldi-python-io, intervaltree, editdistance, resampy, pyloudnorm, pyannote.core, Levenshtein, jiwer, inflect, hydra-core, texterrors, lhotse, g2p-en, pytorch-lightning, pyannote.database, pyannote.metrics, nemo_toolkit
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.3.3
#     Uninstalling pytorch-lightning-2.3.3:
#       Successfully uninstalled pytorch-lightning-2.3.3
# Successfully installed Levenshtein-0.25.1 antlr4-python3-runtime-4.9.3 braceexpand-0.1.7 distance-0.1.3 editdistance-0.8.1 g2p-en-2.1.0 hydra-core-1.3.2 inflect-7.3.1 intervaltree-3.1.0 jiwer-3.0.4 kaldi-python-io-1.2.2 kaldiio-2.18.0 lhotse-1.25.0 lilcom-1.8.0 nemo_toolkit-1.23.0 omegaconf-2.3.0 plac-1.4.3 pyannote.core-5.0.0 pyannote.database-5.1.0 pyannote.metrics-3.2.1 pyloudnorm-0.1.1 pytorch-lightning-2.0.7 rapidfuzz-3.9.4 resampy-0.4.3 sacremoses-0.1.1 sox-1.5.0 texterrors-0.5.1 triton-3.0.0 webdataset-0.1.62 wget-3.2 youtokentome-1.0.6

# %%
# !rm -r /kaggle/working/asr-model-quartznet.zip
# !rm -r /kaggle/working/diarization-dataset.zip
# !rm -r /kaggle/working/wavs/audio_sample_63.wav

# %%
import os
import json

# Directory containing the WAV files
wavs_directory = dataset_path

# Output manifest file path
manifest_path = '/kaggle/working/manifest.json'

# Function to collect WAV files in the directory
def collect_wav_files(directory):
    wav_files = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.wav'):
                wav_files.append(os.path.join(root, file))
    return wav_files

# Function to create the manifest file
def create_manifest(wav_files, manifest_file):
    manifest_entries = []
    for wav_file in wav_files:
        manifest_entry = {
            "audio_filepath": wav_file,
            "offset": 0,
            "duration": None,
            "label": "infer",
            "text": "-",
            "num_speakers": None,
            "rttm_filepath": "/path/to/rttm/file",
            "uem_filepath": "/path/to/uem/filepath"
        }
        manifest_entries.append(manifest_entry)
    
    with open(manifest_file, 'w') as f:
        for entry in manifest_entries:
            json.dump(entry, f)
            f.write('\n')

# Collect all WAV files in the directory
wav_files = collect_wav_files(wavs_directory)

# Create the manifest file
create_manifest(wav_files, manifest_path)

print(f"Manifest file created at: {manifest_path}")
# Out:
# Manifest file created at: /kaggle/working/manifest.json

# %%
config_data = """
# offline_diarization_with_asr.yaml
name: &name "ClusterDiarizer"

num_workers: 1
sample_rate: 16000
batch_size: 16
device: null # can specify a specific device, i.e: cuda:1 (default cuda if cuda available, else cpu)
verbose: True # enable additional logging

diarizer:
  manifest_filepath: "/kaggle/working/manifest.json" # Update this with your manifest file path
  out_dir: "/kaggle/working/outdir" # Update this with your desired output directory
  oracle_vad: False # If True, uses RTTM files provided in the manifest file to get speech activity (VAD) timestamps
  collar: 0.25 # Collar value for scoring
  ignore_overlap: True # Consider or ignore overlap segments while scoring

  vad:
    model_path: vad_multilingual_marblenet # .nemo local model path or pretrained VAD model name 
    external_vad_manifest: null # This option is provided to use external vad and provide its speech activity labels for speaker embeddings extraction. Only one of model_path or external_vad_manifest should be set

    parameters: # Tuned by detection error rate (false alarm + miss) on multilingual ASR evaluation datasets
      window_length_in_sec: 0.63  # Window length in sec for VAD context input 
      shift_length_in_sec: 0.08 # Shift length in sec for generate frame level VAD prediction
      smoothing: False # False or type of smoothing method (eg: median)
      overlap: 0.5 # Overlap ratio for overlapped mean/median smoothing filter
      onset: 0.5 # Onset threshold for detecting the beginning and end of a speech 
      offset: 0.3 # Offset threshold for detecting the end of a speech
      pad_onset: 0.2 # Adding durations before each speech segment 
      pad_offset: 0.2 # Adding durations after each speech segment 
      min_duration_on: 0.5 # Threshold for small non_speech deletion
      min_duration_off: 0.5 # Threshold for short speech segment deletion
      filter_speech_first: True 

  speaker_embeddings:
    model_path: titanet_large # .nemo local model path or pretrained model name (titanet_large, ecapa_tdnn or speakerverification_speakernet)
    parameters:
      window_length_in_sec: [1.9, 1.2, 0.5] # Window length(s) in sec (floating-point number). either a number or a list. ex) 1.5 or [1.5,1.0,0.5]
      shift_length_in_sec: [0.95, 0.6, 0.25] # Shift length(s) in sec (floating-point number). either a number or a list. ex) 0.75 or [0.75,0.5,0.25]
      multiscale_weights: [1,1,1] # Weight for each scale. should be null (for single scale) or a list matched with window/shift scale count. ex) [0.33,0.33,0.33]
      save_embeddings: True # If True, save speaker embeddings in pickle format. This should be True if clustering result is used for other models, such as `msdd_model`.
  
  clustering:
    parameters:
      oracle_num_speakers: False # If True, use num of speakers value provided in manifest file.
      max_num_speakers: 8 # Max number of speakers for each recording. If an oracle number of speakers is passed, this value is ignored.
      enhanced_count_thres: 80 # If the number of segments is lower than this number, enhanced speaker counting is activated.
      max_rp_threshold: 0.25 # Determines the range of p-value search: 0 < p <= max_rp_threshold. 
      sparse_search_volume: 10 # The higher the number, the more values will be examined with more time. 
      maj_vote_spk_count: False  # If True, take a majority vote on multiple p-values to estimate the number of speakers.
      chunk_cluster_count: 50 # Number of forced clusters (overclustering) per unit chunk in long-form audio clustering.
      embeddings_per_chunk: 10000 # Number of embeddings in each chunk for long-form audio clustering. Adjust based on GPU memory capacity. (default: 10000, approximately 40 mins of audio) 

  msdd_model:
    model_path: "diar_msdd_general"  # Update this with your MSDD pretrained model path
    parameters:
      use_speaker_model_from_ckpt: True # If True, use speaker embedding model in checkpoint. If False, the provided speaker embedding model in config will be used.
      infer_batch_size: 16 # Batch size for MSDD inference. 
      sigmoid_threshold: [0.7] # Sigmoid threshold for generating binarized speaker labels. The smaller the more generous on detecting overlaps.
      seq_eval_mode: False # If True, use oracle number of speaker and evaluate F1 score for the given speaker sequences. Default is False.
      split_infer: True # If True, break the input audio clip to short sequences and calculate cluster average embeddings for inference.
      diar_window_length: 50 # The length of split short sequence when split_infer is True.
      overlap_infer_spk_limit: 5 # If the estimated number of speakers are larger than this number, overlap speech is not estimated.
  
  asr:
    model_path: "/kaggle/working/quartznet-CTC-Char-Medium.nemo" # Path to your trained .nemo model
    parameters:
      asr_based_vad: False # If you want to use ASR for VAD
      asr_based_vad_threshold: 1.0
      asr_batch_size: 1 # Adjust based on your hardware capabilities
      decoder_delay_in_sec: null
      word_ts_anchor_offset: null
      word_ts_anchor_pos: "start"
      fix_word_ts_with_VAD: False
      colored_text: False
      print_time: True
      break_lines: False
  
    ctc_decoder_parameters:
      pretrained_language_model: null
      beam_width: 32
      alpha: 0.5
      beta: 2.5

    realigning_lm_parameters:
      arpa_language_model: null
      min_number_of_words: 3
      max_number_of_words: 10
      logprob_diff_threshold: 1.2
"""

# %%
import os

# Ensure the directory exists before writing the file
directory = "/kaggle/working/"
if not os.path.exists(directory):
    os.makedirs(directory)

# Write the config to a .yaml file in the specified directory
with open(os.path.join(directory, "asr_diar.yaml"), "w") as file:
    file.write(config_data)

print(f"Configuration saved to {os.path.abspath(os.path.join(directory, 'asr_diar.yaml'))}")
# Out:
# Configuration saved to /kaggle/working/asr_diar.yaml

# %%
file_path = "/kaggle/working/asr_diar.py"

code = """
from omegaconf import OmegaConf

from nemo.collections.asr.parts.utils.decoder_timestamps_utils import ASRDecoderTimeStamps
from nemo.collections.asr.parts.utils.diarization_utils import OfflineDiarWithASR
from nemo.collections.asr.models import EncDecCTCModel
from nemo.core.config import hydra_runner
from nemo.utils import logging
import torch

@hydra_runner(config_path="/kaggle/working/", config_name="asr_diar.yaml")
def main(cfg):

    logging.info(f'Hydra config: {OmegaConf.to_yaml(cfg)}')

    # ASR inference for words and word timestamps
    if torch.cuda.is_available():
            torch.cuda.empty_cache()
            logging.info("Cleared CUDA cache.")
            
    asr_decoder_ts = ASRDecoderTimeStamps(cfg.diarizer)
    asr_model = asr_decoder_ts.set_asr_model()
    
            
    word_hyp, word_ts_hyp = asr_decoder_ts.run_ASR(asr_model)

    # Create a class instance for matching ASR and diarization results
    asr_diar_offline = OfflineDiarWithASR(cfg.diarizer)
    asr_diar_offline.word_ts_anchor_offset = asr_decoder_ts.word_ts_anchor_offset

    # Diarization inference for speaker labels
    diar_hyp, diar_score = asr_diar_offline.run_diarization(cfg, word_ts_hyp)
    trans_info_dict = asr_diar_offline.get_transcript_with_speaker_labels(diar_hyp, word_hyp, word_ts_hyp)

    # If RTTM is provided and DER evaluation
    if diar_score is not None:
        # Get session-level diarization error rate and speaker counting error
        der_results = OfflineDiarWithASR.gather_eval_results(
            diar_score=diar_score,
            audio_rttm_map_dict=asr_diar_offline.AUDIO_RTTM_MAP,
            trans_info_dict=trans_info_dict,
            root_path=asr_diar_offline.root_path,
        )

        # Calculate WER and cpWER if reference CTM files exist
        wer_results = OfflineDiarWithASR.evaluate(
            hyp_trans_info_dict=trans_info_dict,
            audio_file_list=asr_diar_offline.audio_file_list,
            ref_ctm_file_list=asr_diar_offline.ctm_file_list,
        )

        # Print average DER, WER and cpWER
        OfflineDiarWithASR.print_errors(der_results=der_results, wer_results=wer_results)

        # Save detailed session-level evaluation results in `root_path`.
        OfflineDiarWithASR.write_session_level_result_in_csv(
            der_results=der_results,
            wer_results=wer_results,
            root_path=asr_diar_offline.root_path,
            csv_columns=asr_diar_offline.csv_columns,
        )


if __name__ == '__main__':
    main()

"""

with open(file_path, "w") as file:
    file.write(code)

print("File created successfully!")
# Out:
# File created successfully!

# %%
import torch
torch.cuda.empty_cache()

# %%
# !pip install --upgrade torchvision
# !pip install --upgrade torchaudio
# !pip install --upgrade pytorch-lightning
# Out:
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.16.2)
# Collecting torchvision
#   Using cached torchvision-0.18.1-cp310-cp310-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Collecting torch==2.3.1 (from torchvision)
#   Using cached torch-2.3.1-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchvision) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchvision) (1.13.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchvision) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchvision) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchvision) (2024.5.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.3.1->torchvision)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.3.1->torchvision)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.3.1->torchvision)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.3.1->torchvision)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.3.1->torchvision)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.3.1->torchvision)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.3.1->torchvision)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.3.1->torchvision)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.3.1->torchvision)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.3.1->torchvision)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.3.1->torchvision)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.3.1 (from torch==2.3.1->torchvision)
#   Using cached triton-2.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.1->torchvision)
#   Using cached nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch==2.3.1->torchvision) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch==2.3.1->torchvision) (1.3.0)
# Using cached torchvision-0.18.1-cp310-cp310-manylinux1_x86_64.whl (7.0 MB)
# Downloading torch-2.3.1-cp310-cp310-manylinux1_x86_64.whl (779.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 2.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 82.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 69.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 34.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 6.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 5.3 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 13.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 8.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 9.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 5.6 MB/s eta 0:00:00
# Downloading triton-2.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 9.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 73.2 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 3.0.0
#     Uninstalling triton-3.0.0:
#       Successfully uninstalled triton-3.0.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.2
#     Uninstalling torch-2.1.2:
#       Successfully uninstalled torch-2.1.2
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.16.2
#     Uninstalling torchvision-0.16.2:
#       Successfully uninstalled torchvision-0.16.2
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 torch-2.3.1 torchvision-0.18.1 triton-2.3.1
# Requirement already satisfied: torchaudio in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Collecting torchaudio
#   Downloading torchaudio-2.3.1-cp310-cp310-manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: torch==2.3.1 in /opt/conda/lib/python3.10/site-packages (from torchaudio) (2.3.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchaudio) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchaudio) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchaudio) (1.13.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchaudio) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchaudio) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchaudio) (2024.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchaudio) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchaudio) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchaudio) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchaudio) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchaudio) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchaudio) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchaudio) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchaudio) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchaudio) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchaudio) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchaudio) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /opt/conda/lib/python3.10/site-packages (from torch==2.3.1->torchaudio) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.1->torchaudio) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch==2.3.1->torchaudio) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch==2.3.1->torchaudio) (1.3.0)
# Downloading torchaudio-2.3.1-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 39.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: torchaudio
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.1.2
#     Uninstalling torchaudio-2.1.2:
#       Successfully uninstalled torchaudio-2.1.2
# Successfully installed torchaudio-2.3.1
# Requirement already satisfied: pytorch-lightning in /opt/conda/lib/python3.10/site-packages (2.0.7)
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-2.3.3-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy>=1.17.2 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (1.26.4)
# Requirement already satisfied: torch>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (2.3.1)
# Requirement already satisfied: tqdm>=4.57.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.66.4)
# Requirement already satisfied: PyYAML>=5.4 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (6.0.1)
# Requirement already satisfied: fsspec>=2022.5.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2024.5.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (1.4.0.post0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.9.0)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (0.11.3.post0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.9.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (69.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->pytorch-lightning) (3.1.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-lightning) (3.13.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-lightning) (1.13.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-lightning) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-lightning) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-lightning) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-lightning) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-lightning) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-lightning) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-lightning) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-lightning) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-lightning) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-lightning) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-lightning) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-lightning) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-lightning) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0.0->pytorch-lightning) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.0->pytorch-lightning) (12.5.82)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2.0.0->pytorch-lightning) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=2.0.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (3.6)
# Downloading pytorch_lightning-2.3.3-py3-none-any.whl (812 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.3/812.3 kB 15.0 MB/s eta 0:00:0000:01
# Installing collected packages: pytorch-lightning
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.0.7
#     Uninstalling pytorch-lightning-2.0.7:
#       Successfully uninstalled pytorch-lightning-2.0.7
# Successfully installed pytorch-lightning-2.3.3

# %%
# !python /kaggle/working/asr_diar.py
# Out:
# [NeMo W 2024-07-23 23:28:34 nemo_logging:349] /opt/conda/lib/python3.10/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
#     See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#       ret = run_job(
#
# [NeMo I 2024-07-23 23:28:34 asr_diar:14] Hydra config: name: ClusterDiarizer
#     num_workers: 1
#     sample_rate: 16000
#     batch_size: 16
#     device: null
#     verbose: true
#     diarizer:
#       manifest_filepath: /kaggle/working/manifest.json
#       out_dir: /kaggle/working/outdir
#       oracle_vad: false
#       collar: 0.25
#       ignore_overlap: true
#       vad:
#         model_path: vad_multilingual_marblenet
#         external_vad_manifest: null
#         parameters:
#           window_length_in_sec: 0.63
#           shift_length_in_sec: 0.08
#           smoothing: false
#           overlap: 0.5
#           onset: 0.5
#           offset: 0.3
#           pad_onset: 0.2
#           pad_offset: 0.2
#           min_duration_on: 0.5
#           min_duration_off: 0.5
#           filter_speech_first: true
#       speaker_embeddings:
#         model_path: titanet_large
#         parameters:
#           window_length_in_sec:
#           - 1.9
#           - 1.2
#           - 0.5
#           shift_length_in_sec:
#           - 0.95
#           - 0.6
#           - 0.25
#           multiscale_weights:
#           - 1
#           - 1
#           - 1
#           save_embeddings: true
#       clustering:
#         parameters:
#           oracle_num_speakers: false
#           max_num_speakers: 8
#           enhanced_count_thres: 80
#           max_rp_threshold: 0.25
#           sparse_search_volume: 10
#           maj_vote_spk_count: false
#           chunk_cluster_count: 50
#           embeddings_per_chunk: 10000
#       msdd_model:
#         model_path: diar_msdd_general
#         parameters:
#           use_speaker_model_from_ckpt: true
#           infer_batch_size: 16
#           sigmoid_threshold:
#           - 0.7
#           seq_eval_mode: false
#           split_infer: true
#           diar_window_length: 50
#           overlap_infer_spk_limit: 5
#       asr:
#         model_path: /kaggle/working/quartznet-CTC-Char-Medium.nemo
#         parameters:
#           asr_based_vad: false
#           asr_based_vad_threshold: 1.0
#           asr_batch_size: 1
#           decoder_delay_in_sec: null
#           word_ts_anchor_offset: null
#           word_ts_anchor_pos: start
#           fix_word_ts_with_VAD: false
#           colored_text: false
#           print_time: true
#           break_lines: false
#         ctc_decoder_parameters:
#           pretrained_language_model: null
#           beam_width: 32
#           alpha: 0.5
#           beta: 2.5
#         realigning_lm_parameters:
#           arpa_language_model: null
#           min_number_of_words: 3
#           max_number_of_words: 10
#           logprob_diff_threshold: 1.2
#
# [NeMo I 2024-07-23 23:28:34 asr_diar:19] Cleared CUDA cache.
# [NeMo I 2024-07-23 23:28:34 speaker_utils:93] Number of files to diarize: 130
# [NeMo W 2024-07-23 23:28:34 modelPT:165] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /kaggle/working/train_manifest.json
#     labels:
#     - ' '
#     - ء
#     - ا
#     - أ
#     - إ
#     - آ
#     - ب
#     - ت
#     - ث
#     - ج
#     - ح
#     - خ
#     - د
#     - ذ
#     - ر
#     - ز
#     - س
#     - ش
#     - ص
#     - ض
#     - ط
#     - ظ
#     - ع
#     - غ
#     - ف
#     - ق
#     - ك
#     - ل
#     - م
#     - ن
#     - ه
#     - و
#     - ي
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: true
#     num_workers: 8
#     pin_memory: true
#     trim_silence: false
#     max_duration: 16.7
#     min_duration: 0.1
#     is_tarred: false
#     tarred_audio_filepaths: null
#     shuffle_n: 2048
#     bucketing_strategy: synced_randomized
#     bucketing_batch_size: null
#
# [NeMo W 2024-07-23 23:28:34 modelPT:172] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /kaggle/working/dev_manifest.json
#     labels:
#     - ' '
#     - ء
#     - ا
#     - أ
#     - إ
#     - آ
#     - ب
#     - ت
#     - ث
#     - ج
#     - ح
#     - خ
#     - د
#     - ذ
#     - ر
#     - ز
#     - س
#     - ش
#     - ص
#     - ض
#     - ط
#     - ظ
#     - ع
#     - غ
#     - ف
#     - ق
#     - ك
#     - ل
#     - م
#     - ن
#     - ه
#     - و
#     - ي
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: false
#     use_start_end_token: false
#     num_workers: 8
#     pin_memory: true
#
# [NeMo W 2024-07-23 23:28:34 modelPT:178] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: /kaggle/working/test_manifest.json
#     labels:
#     - ' '
#     - ء
#     - ا
#     - أ
#     - إ
#     - آ
#     - ب
#     - ت
#     - ث
#     - ج
#     - ح
#     - خ
#     - د
#     - ذ
#     - ر
#     - ز
#     - س
#     - ش
#     - ص
#     - ض
#     - ط
#     - ظ
#     - ع
#     - غ
#     - ف
#     - ق
#     - ك
#     - ل
#     - م
#     - ن
#     - ه
#     - و
#     - ي
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: false
#     use_start_end_token: false
#     num_workers: 8
#     pin_memory: true
#
# [NeMo I 2024-07-23 23:28:34 features:289] PADDING: 0
# [NeMo I 2024-07-23 23:28:34 ctc_models:68]
#     Replacing placeholder number of classes (-1) with actual number of classes - 33
# [NeMo I 2024-07-23 23:28:34 conv_asr:428] num_classes of ConvASRDecoder is set to the size of the vocabulary: 33.
# [NeMo I 2024-07-23 23:28:35 save_restore_connector:249] Model EncDecCTCModel was successfully restored from /kaggle/working/quartznet-CTC-Char-Medium.nemo.
# [NeMo W 2024-07-23 23:28:35 decoder_timestamps_utils:176] `ctc_decode` was set to True. Note that this is ignored.
# Transcribing: 100%|███████████████████████████| 130/130 [00:29<00:00,  4.48it/s]
# [NeMo I 2024-07-23 23:29:04 speaker_utils:93] Number of files to diarize: 130
# [NeMo I 2024-07-23 23:29:04 clustering_diarizer:127] Loading pretrained vad_multilingual_marblenet model from NGC
# [NeMo I 2024-07-23 23:29:04 cloud:58] Found existing object /root/.cache/torch/NeMo/NeMo_1.23.0/vad_multilingual_marblenet/670f425c7f186060b7a7268ba6dfacb2/vad_multilingual_marblenet.nemo.
# [NeMo I 2024-07-23 23:29:04 cloud:64] Re-using file from: /root/.cache/torch/NeMo/NeMo_1.23.0/vad_multilingual_marblenet/670f425c7f186060b7a7268ba6dfacb2/vad_multilingual_marblenet.nemo
# [NeMo I 2024-07-23 23:29:04 common:924] Instantiating model from pre-trained checkpoint
# [NeMo W 2024-07-23 23:29:04 modelPT:165] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /manifests/ami_train_0.63.json,/manifests/freesound_background_train.json,/manifests/freesound_laughter_train.json,/manifests/fisher_2004_background.json,/manifests/fisher_2004_speech_sampled.json,/manifests/google_train_manifest.json,/manifests/icsi_all_0.63.json,/manifests/musan_freesound_train.json,/manifests/musan_music_train.json,/manifests/musan_soundbible_train.json,/manifests/mandarin_train_sample.json,/manifests/german_train_sample.json,/manifests/spanish_train_sample.json,/manifests/french_train_sample.json,/manifests/russian_train_sample.json
#     sample_rate: 16000
#     labels:
#     - background
#     - speech
#     batch_size: 256
#     shuffle: true
#     is_tarred: false
#     tarred_audio_filepaths: null
#     tarred_shard_strategy: scatter
#     augmentor:
#       shift:
#         prob: 0.5
#         min_shift_ms: -10.0
#         max_shift_ms: 10.0
#       white_noise:
#         prob: 0.5
#         min_level: -90
#         max_level: -46
#         norm: true
#       noise:
#         prob: 0.5
#         manifest_path: /manifests/noise_0_1_musan_fs.json
#         min_snr_db: 0
#         max_snr_db: 30
#         max_gain_db: 300.0
#         norm: true
#       gain:
#         prob: 0.5
#         min_gain_dbfs: -10.0
#         max_gain_dbfs: 10.0
#         norm: true
#     num_workers: 16
#     pin_memory: true
#
# [NeMo W 2024-07-23 23:29:04 modelPT:172] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /manifests/ami_dev_0.63.json,/manifests/freesound_background_dev.json,/manifests/freesound_laughter_dev.json,/manifests/ch120_moved_0.63.json,/manifests/fisher_2005_500_speech_sampled.json,/manifests/google_dev_manifest.json,/manifests/musan_music_dev.json,/manifests/mandarin_dev.json,/manifests/german_dev.json,/manifests/spanish_dev.json,/manifests/french_dev.json,/manifests/russian_dev.json
#     sample_rate: 16000
#     labels:
#     - background
#     - speech
#     batch_size: 256
#     shuffle: false
#     val_loss_idx: 0
#     num_workers: 16
#     pin_memory: true
#
# [NeMo W 2024-07-23 23:29:04 modelPT:178] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: null
#     sample_rate: 16000
#     labels:
#     - background
#     - speech
#     batch_size: 128
#     shuffle: false
#     test_loss_idx: 0
#
# [NeMo I 2024-07-23 23:29:04 features:289] PADDING: 16
# [NeMo I 2024-07-23 23:29:04 save_restore_connector:249] Model EncDecClassificationModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.23.0/vad_multilingual_marblenet/670f425c7f186060b7a7268ba6dfacb2/vad_multilingual_marblenet.nemo.
# [NeMo I 2024-07-23 23:29:04 clustering_diarizer:157] Loading pretrained titanet_large model from NGC
# [NeMo I 2024-07-23 23:29:04 cloud:58] Found existing object /root/.cache/torch/NeMo/NeMo_1.23.0/titanet-l/11ba0924fdf87c049e339adbf6899d48/titanet-l.nemo.
# [NeMo I 2024-07-23 23:29:04 cloud:64] Re-using file from: /root/.cache/torch/NeMo/NeMo_1.23.0/titanet-l/11ba0924fdf87c049e339adbf6899d48/titanet-l.nemo
# [NeMo I 2024-07-23 23:29:04 common:924] Instantiating model from pre-trained checkpoint
# [NeMo W 2024-07-23 23:29:08 modelPT:165] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /manifests/combined_fisher_swbd_voxceleb12_librispeech/train.json
#     sample_rate: 16000
#     labels: null
#     batch_size: 64
#     shuffle: true
#     is_tarred: false
#     tarred_audio_filepaths: null
#     tarred_shard_strategy: scatter
#     augmentor:
#       noise:
#         manifest_path: /manifests/noise/rir_noise_manifest.json
#         prob: 0.5
#         min_snr_db: 0
#         max_snr_db: 15
#       speed:
#         prob: 0.5
#         sr: 16000
#         resample_type: kaiser_fast
#         min_speed_rate: 0.95
#         max_speed_rate: 1.05
#     num_workers: 15
#     pin_memory: true
#
# [NeMo W 2024-07-23 23:29:08 modelPT:172] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /manifests/combined_fisher_swbd_voxceleb12_librispeech/dev.json
#     sample_rate: 16000
#     labels: null
#     batch_size: 128
#     shuffle: false
#     num_workers: 15
#     pin_memory: true
#
# [NeMo I 2024-07-23 23:29:08 features:289] PADDING: 16
# [NeMo I 2024-07-23 23:29:09 save_restore_connector:249] Model EncDecSpeakerLabelModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.23.0/titanet-l/11ba0924fdf87c049e339adbf6899d48/titanet-l.nemo.
# [NeMo W 2024-07-23 23:29:09 clustering_diarizer:411] Deleting previous clustering diarizer outputs.
# [NeMo I 2024-07-23 23:29:09 speaker_utils:93] Number of files to diarize: 130
# [NeMo I 2024-07-23 23:29:09 clustering_diarizer:309] Split long audio file to avoid CUDA memory issue
# splitting manifest: 100%|█████████████████████| 130/130 [00:02<00:00, 52.47it/s]
# [NeMo I 2024-07-23 23:29:11 vad_utils:107] The prepared manifest file exists. Overwriting!
# [NeMo I 2024-07-23 23:29:11 classification_models:273] Perform streaming frame-level VAD
# [NeMo I 2024-07-23 23:29:11 collections:445] Filtered duration for loading collection is  0.00 hours.
# [NeMo I 2024-07-23 23:29:11 collections:446] Dataset loaded with 274 items, total duration of  2.81 hours.
# [NeMo I 2024-07-23 23:29:11 collections:448] # 274 files loaded accounting to # 1 labels
# vad: 100%|████████████████████████████████████| 274/274 [00:10<00:00, 26.71it/s]
# [NeMo I 2024-07-23 23:29:21 clustering_diarizer:262] Converting frame level prediction to speech/no-speech segment in start and end times format.
# creating speech segments: 100%|██████████████| 130/130 [00:01<00:00, 120.52it/s]
# [NeMo I 2024-07-23 23:29:22 clustering_diarizer:287] Subsegmentation for embedding extraction: scale0, /kaggle/working/outdir/speaker_outputs/subsegments_scale0.json
# [NeMo I 2024-07-23 23:29:23 clustering_diarizer:343] Extracting embeddings for Diarization
# [NeMo I 2024-07-23 23:29:23 collections:445] Filtered duration for loading collection is  0.00 hours.
# [NeMo I 2024-07-23 23:29:23 collections:446] Dataset loaded with 10254 items, total duration of  5.38 hours.
# [NeMo I 2024-07-23 23:29:23 collections:448] # 10254 files loaded accounting to # 1 labels
# [1/3] extract embeddings: 100%|███████████████| 641/641 [00:26<00:00, 24.15it/s]
# [NeMo I 2024-07-23 23:29:50 clustering_diarizer:389] Saved embedding files to /kaggle/working/outdir/speaker_outputs/embeddings
# [NeMo I 2024-07-23 23:29:50 clustering_diarizer:287] Subsegmentation for embedding extraction: scale1, /kaggle/working/outdir/speaker_outputs/subsegments_scale1.json
# [NeMo I 2024-07-23 23:29:50 clustering_diarizer:343] Extracting embeddings for Diarization
# [NeMo I 2024-07-23 23:29:50 collections:445] Filtered duration for loading collection is  0.00 hours.
# [NeMo I 2024-07-23 23:29:50 collections:446] Dataset loaded with 16253 items, total duration of  5.40 hours.
# [NeMo I 2024-07-23 23:29:50 collections:448] # 16253 files loaded accounting to # 1 labels
# [2/3] extract embeddings: 100%|█████████████| 1016/1016 [00:33<00:00, 30.05it/s]
# [NeMo I 2024-07-23 23:30:25 clustering_diarizer:389] Saved embedding files to /kaggle/working/outdir/speaker_outputs/embeddings
# [NeMo I 2024-07-23 23:30:25 clustering_diarizer:287] Subsegmentation for embedding extraction: scale2, /kaggle/working/outdir/speaker_outputs/subsegments_scale2.json
# [NeMo I 2024-07-23 23:30:26 clustering_diarizer:343] Extracting embeddings for Diarization
# [NeMo I 2024-07-23 23:30:26 collections:445] Filtered duration for loading collection is  0.00 hours.
# [NeMo I 2024-07-23 23:30:26 collections:446] Dataset loaded with 39124 items, total duration of  5.43 hours.
# [NeMo I 2024-07-23 23:30:26 collections:448] # 39124 files loaded accounting to # 1 labels
# [3/3] extract embeddings: 100%|█████████████| 2446/2446 [01:01<00:00, 39.71it/s]
# [NeMo I 2024-07-23 23:31:29 clustering_diarizer:389] Saved embedding files to /kaggle/working/outdir/speaker_outputs/embeddings
# clustering: 100%|█████████████████████████████| 130/130 [00:20<00:00,  6.43it/s]
# [NeMo I 2024-07-23 23:31:50 clustering_diarizer:464] Outputs are saved in /kaggle/working/outdir directory
# [NeMo W 2024-07-23 23:31:50 der:185] Check if each ground truth RTTMs were present in the provided manifest file. Skipping calculation of Diariazation Error Rate
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_55 n_spk: 1
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_183 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_57 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_75 n_spk: 1
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_12 n_spk: 3
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_64 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_100 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_39 n_spk: 3
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_135 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_110 n_spk: 1
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_95 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_101 n_spk: 3
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_167 n_spk: 3
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_187 n_spk: 4
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_14 n_spk: 1
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_96 n_spk: 1
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_85 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_78 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_80 n_spk: 3
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_19 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_74 n_spk: 1
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_192 n_spk: 3
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_128 n_spk: 1
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_29 n_spk: 4
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_88 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_188 n_spk: 3
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_189 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_109 n_spk: 3
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_180 n_spk: 1
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_154 n_spk: 3
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_200 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_59 n_spk: 5
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_191 n_spk: 3
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_186 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_108 n_spk: 1
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_195 n_spk: 1
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_153 n_spk: 3
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_25 n_spk: 3
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_150 n_spk: 5
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_177 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_119 n_spk: 1
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_79 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_31 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_81 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_92 n_spk: 1
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_129 n_spk: 3
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_136 n_spk: 5
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_89 n_spk: 1
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_33 n_spk: 1
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_22 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_170 n_spk: 7
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_10 n_spk: 3
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_18 n_spk: 3
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_125 n_spk: 4
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_16 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_65 n_spk: 1
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_102 n_spk: 3
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_155 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_40 n_spk: 6
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_82 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_139 n_spk: 2
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_196 n_spk: 3
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_24 n_spk: 3
# [NeMo I 2024-07-23 23:31:50 diarization_utils:876] Creating results for Session: audio_sample_3 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_43 n_spk: 7
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_72 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_50 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_120 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_2 n_spk: 3
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_197 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_199 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_141 n_spk: 3
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_164 n_spk: 4
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_73 n_spk: 5
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_6 n_spk: 3
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_198 n_spk: 3
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_127 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_160 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_97 n_spk: 4
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_94 n_spk: 5
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_103 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_87 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_201 n_spk: 4
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_69 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_162 n_spk: 3
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_138 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_132 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_112 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_147 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_41 n_spk: 8
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_117 n_spk: 4
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_161 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_83 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_124 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_52 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_46 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_149 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_60 n_spk: 3
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_9 n_spk: 3
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_172 n_spk: 3
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_34 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_104 n_spk: 3
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_144 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_76 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_175 n_spk: 3
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_106 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_126 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_56 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_49 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_151 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_113 n_spk: 3
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_30 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_13 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_146 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_20 n_spk: 3
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_28 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_90 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_35 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_118 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_21 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_44 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_51 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_11 n_spk: 4
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_42 n_spk: 6
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_159 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_1 n_spk: 1
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_140 n_spk: 6
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_194 n_spk: 3
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_38 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:876] Creating results for Session: audio_sample_47 n_spk: 2
# [NeMo I 2024-07-23 23:31:51 diarization_utils:749] Diarization with ASR output files are saved in: /kaggle/working/outdir/pred_rttms

# %%
import os
import json

# Directory containing the .txt files
input_dir = '/kaggle/working/outdir/pred_rttms'
output_dir = '/kaggle/working/submission'

# Create the output directory if it does not exist
os.makedirs(output_dir, exist_ok=True)

def process_line(line):
    start = end = speaker = None  # Initialize variables
    text = ""

    try:
        # Strip any leading or trailing whitespace
        line = line.strip()
        
        # Split the line into its components
        time_range, rest = line.split('] ', 1)
        start_time, end_time = time_range[1:].split(' - ')
        rest_parts = rest.split(': ', 1)

        if len(rest_parts) == 2:
            speaker, text = rest_parts
        else:
            speaker = rest_parts[0]
        
        # Extract start and end times
        start = float(start_time.split(':')[0]) * 60 + float(start_time.split(':')[1])
        end = float(end_time.split(':')[0]) * 60 + float(end_time.split(':')[1])
        
        # Extract speaker number, clean up any trailing colons or spaces, and ensure it's a valid integer
        if speaker:
            speaker = speaker.replace('speaker_', '').replace(':', '').strip()
            speaker = int(speaker) if speaker.isdigit() else 0
        else:
            speaker = 0

    except ValueError as e:
        # Print the error message and line that caused it
        print(f"Error processing line: '{line}'")
        print(f"Exception: {e}")
        # Provide default values in case of error
        start = end = 0.0
        speaker = 0
    
    # Return the processed entry
    return {
        'start': start,
        'end': end,
        'speaker': speaker,
        'text': text.strip() if text else ""
    }

# Process each .txt file
for txt_filename in os.listdir(input_dir):
    if txt_filename.endswith('.txt'):
        txt_file_path = os.path.join(input_dir, txt_filename)
        
        # Create corresponding .json filename
        json_filename = txt_filename.replace('.txt', '.json')
        json_file_path = os.path.join(output_dir, json_filename)
        
        # Process the .txt file
        with open(txt_file_path, 'r', encoding='utf-8') as file:
            lines = file.readlines()
        
        # Convert the content to the desired JSON format
        entries = []
        for line in lines:
            entry = process_line(line)
            entries.append(entry)
        
        # Write to the .json file
        with open(json_file_path, 'w', encoding='utf-8') as json_file:
            json.dump(entries, json_file, ensure_ascii=False, indent=4)

print("Conversion complete.")
# Out:
# Conversion complete.

# %%
# !zip -r submission.zip /kaggle/working/submission
# Out:
#   adding: kaggle/working/submission/ (stored 0%)
